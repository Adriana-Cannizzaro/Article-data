# %%
chemin = '/Users/adriana/Desktop/datas_MRI_NPI_.xlsx'

# %%
import pandas

# %%
df = pandas.read_excel(chemin)

# %%
df
# Out:
#               MRI_subjects   RID VISCODE2 Group  Dx_change  Follow-up_change  \
# 0    ADNI_011_S_0002_ses-1     2      v00    CN          0               NaN
# 1    ADNI_011_S_0003_ses-1     3      v00    AD          0               NaN
# 2    ADNI_011_S_0005_ses-1     5      v00    CN          0               NaN
# 3    ADNI_100_S_0006_ses-1     6      v00   MCI          0               NaN
# 4    ADNI_011_S_0008_ses-1     8      v00    CN          0               NaN
# ..                     ...   ...      ...   ...        ...               ...
# 760  ADNI_041_S_1425_ses-1  1425      v00   MCI          3              36.0
# 761  ADNI_137_S_1426_ses-1  1426      v00   MCI          0               NaN
# 762  ADNI_127_S_1427_ses-1  1427      v00   MCI          3              12.0
# 763  ADNI_128_S_1430_ses-1  1430      v00    AD          0               NaN
# 764  ADNI_041_S_1435_ses-1  1435      v00    AD          0               NaN
#
# ...

# %%
groupby_group = df.groupby ('Group')

# %%
groupby_group.mean ()
# Out:
#               RID  Dx_change  Follow-up_change        AGE    MMSCORE  \
# Group
# AD     786.902857   0.017143         24.000000  75.457143  23.451429
# CN     580.179372   0.094170         29.000000  75.825112  29.094170
# MCI    767.806540   1.272480         19.566879  74.831063  27.087193
#
#        CDMEMORY  CDGLOBAL  GDMEMORY   GDTOTAL   FAQTOTAL  ...    VLa_THAR  \
# Group                                                     ...
# AD     0.982857  0.734286  0.531429  1.611429  12.788571  ...  562.595396
# CN     0.000000  0.000000  0.076233  0.843049   0.139013  ...  574.527304
# MCI    0.566757  0.498638  0.512262  1.561308   3.727520  ...  580.974221
#
#          VLp_THAR    VM_THAR    VPL_THAR  WholeThalamus_THAR  \
# Group
# AD     755.966965  22.295572  889.622461         5998.975499
# CN     760.272914  22.667210  875.834669         6153.933090
# MCI    775.939000  23.032522  904.855925         6147.370097
#
# ...

# %%
for group, valeur in groupby_group ['NPIDSEV']: 
    print(group, valeur.mean ())
# Out:
# AD 0.3942857142857143
# CN 0.06278026905829596
# MCI 0.23705722070844687

# %%
for group, valeur in groupby_group ['NPIGSEV']:
    print(group, valeur.mean ())
# Out:
# AD 0.4742857142857143
# CN 0.013452914798206279
# MCI 0.1989100817438692

# %%
for group, valeur in groupby_group ['NPIESEV']:
    print(group, valeur.mean ())
# Out:
# AD 0.4114285714285714
# CN 0.04932735426008968
# MCI 0.2125340599455041
