# %%
import pandas

# %%
# reading the files
file1 = pandas.read_excel('/Users/adriana/Desktop/fs_all_stats_20200811.xlsx')
file2= pandas.read_excel('/Users/adriana/Desktop/datas_MRI_NPI_.xlsx')

# %%
file1
# Out:
#               MRI_subjects  medulla_Brainstem  pons_Brainstem  scp_Brainstem  \
# 0    ADNI_098_S_0667_ses-1        5643.211957    24629.257546     385.313737
# 1    ADNI_002_S_4799_ses-1        4686.783288    14071.953319     258.481285
# 2    ADNI_057_S_1007_ses-1        4996.309339    16304.440717     240.824893
# 3    ADNI_012_S_0803_ses-1        3842.041560    13055.761734     274.648623
# 4    ADNI_128_S_0310_ses-1        4927.343238    16738.292414     320.708310
# ..                     ...                ...             ...            ...
# 819  ADNI_031_S_0830_ses-1        4017.302604    13780.984360     206.622946
# 820  ADNI_010_S_0067_ses-1        4403.467472    16306.947318     253.093936
# 821  ADNI_023_S_0058_ses-1        4147.965314    14887.427071     259.404414
# 822  ADNI_011_S_0168_ses-1        4194.920039    18113.975692     318.123936
# 823  ADNI_032_S_0095_ses-1        4608.033873    15586.685594     249.990507
#
# ...

# %%
file2
# Out:
#               MRI_subjects   RID VISCODE2 Group  Dx_change  Follow-up_change  \
# 0    ADNI_011_S_0002_ses-1     2      v00    CN          0               NaN
# 1    ADNI_011_S_0003_ses-1     3      v00    AD          0               NaN
# 2    ADNI_011_S_0005_ses-1     5      v00    CN          0               NaN
# 3    ADNI_100_S_0006_ses-1     6      v00   MCI          0               NaN
# 4    ADNI_011_S_0008_ses-1     8      v00    CN          0               NaN
# ..                     ...   ...      ...   ...        ...               ...
# 760  ADNI_041_S_1425_ses-1  1425      v00   MCI          3              36.0
# 761  ADNI_137_S_1426_ses-1  1426      v00   MCI          0               NaN
# 762  ADNI_127_S_1427_ses-1  1427      v00   MCI          3              12.0
# 763  ADNI_128_S_1430_ses-1  1430      v00    AD          0               NaN
# 764  ADNI_041_S_1435_ses-1  1435      v00    AD          0               NaN
#
# ...

# %%
# merging the files
finalfile = pandas.merge(file1, file2, left_on= 'MRI_subjects', right_on= 'MRI_subjects')

# %%
finalfile
# Out:
#               MRI_subjects  medulla_Brainstem_x  pons_Brainstem_x  \
# 0    ADNI_098_S_0667_ses-1          5643.211957      24629.257546
# 1    ADNI_057_S_1007_ses-1          4996.309339      16304.440717
# 2    ADNI_012_S_0803_ses-1          3842.041560      13055.761734
# 3    ADNI_128_S_0310_ses-1          4927.343238      16738.292414
# 4    ADNI_130_S_0449_ses-1          3651.229328      13408.207282
# ..                     ...                  ...               ...
# 584  ADNI_031_S_0830_ses-1          4017.302604      13780.984360
# 585  ADNI_010_S_0067_ses-1          4403.467472      16306.947318
# 586  ADNI_023_S_0058_ses-1          4147.965314      14887.427071
# 587  ADNI_011_S_0168_ses-1          4194.920039      18113.975692
# 588  ADNI_032_S_0095_ses-1          4608.033873      15586.685594
#
#      scp_Brainstem_x  midbrain_Brainstem_x  wholeBrainstem_Brainstem_x  \
# 0         385.313737           8299.677682                38957.460922
# ...
